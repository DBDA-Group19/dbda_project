# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.4.1.tar.gz (310.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.4.1-py2.py3-none-any.whl size=311285398 sha256=538e8f433eac500ecab7491479be77c64d6e3f4b06290d431f54a25f3c8ff59d
#   Stored in directory: /root/.cache/pip/wheels/0d/77/a3/ff2f74cc9ab41f8f594dabf0579c2a7c6de920d584206e0834
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.4.1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip gdrive/My\ Drive/1c3719ea59.zip > /dev/null

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (9.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from pyarrow) (1.22.4)

# %%
import pandas as pd
df=pd.read_parquet('/content/1c3719ea59.parquet')

# %%
df.to_csv('output_file.csv',index=False)

# %%
df1=pd.read_csv('/content/output_file.csv')

# %%
df1
# Out:
#               Time      AccV     AccML     AccAP
# 0                0 -0.093750  0.062500  0.828125
# 1                1 -0.000049 -0.015584 -0.981767
# 2                2  0.000000 -0.015625 -1.031177
# 3                3  0.000000 -0.015625 -1.031250
# 4                4  0.000000 -0.015625 -1.031250
# ...            ...       ...       ...       ...
# 65879772  65879772  0.000000  0.000000  0.000000
# 65879773  65879773  0.000000  0.000000  0.000000
# 65879774  65879774  0.000000  0.000000  0.000000
# 65879775  65879775  0.000000  0.000000  0.000000
# 65879776  65879776  0.000000  0.000000  0.000000
#
# [65879777 rows x 4 columns]

# %%
df1.isnull().sum()
# Out:
# Time     0
# AccV     0
# AccML    0
# AccAP    0
# dtype: int64

# %%
df1.describe()
# Out:
#                Time          AccV         AccML         AccAP
# count  6.587978e+07  6.587978e+07  6.587978e+07  6.587978e+07
# mean   3.293989e+07 -2.839254e-01  2.737847e-02  2.908443e-01
# std    1.901785e+07  3.832492e-01  2.841237e-01  4.546733e-01
# min    0.000000e+00 -6.831497e+00 -6.239477e+00 -7.618043e+00
# 25%    1.646994e+07 -5.000000e-01 -1.150616e-02  0.000000e+00
# 50%    3.293989e+07 -1.093750e-01  0.000000e+00  0.000000e+00
# 75%    4.940983e+07  0.000000e+00  1.250000e-01  8.281250e-01
# max    6.587978e+07  5.911802e+00  5.116779e+00  5.687390e+00

# %%
df1.corr()
# Out:
#            Time      AccV     AccML     AccAP
# Time   1.000000  0.414062 -0.087794 -0.322320
# AccV   0.414062  1.000000  0.042084  0.379626
# AccML -0.087794  0.042084  1.000000  0.160374
# AccAP -0.322320  0.379626  0.160374  1.000000

# %%
import seaborn as sns
cm=df1.corr()
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >
