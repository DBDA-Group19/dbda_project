# %%
df = spark.read.parquet("dbfs:/FileStore/tables/1c3719ea59.parquet")

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Time: long (nullable = true)
#  |-- AccV: double (nullable = true)
#  |-- AccML: double (nullable = true)
#  |-- AccAP: double (nullable = true)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <command-3026931872061040>:1
# ----> 1 px.pie(ma,names='parkinson')
#
# File /databricks/python/lib/python3.9/site-packages/plotly/express/_chart_types.py:1462, in pie(data_frame, names, values, color, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, opacity, hole)
#    1460 else:
#    1461     layout_patch = {}
# -> 1462 return make_figure(
#    1463     args=locals(),
#    1464     constructor=go.Pie,
#    1465     trace_patch=dict(showlegend=(names is not None), hole=hole),
#    1466     layout_patch=layout_patch,
#    1467 )
#
# File /databricks/python/lib/python3.9/site-packages/plotly/express/_core.py:1945, in make_figure(args, constructor, trace_patch, layout_patch)
#    1942 layout_patch = layout_patch or {}
#    1943 apply_default_cascade(args)
# ...
