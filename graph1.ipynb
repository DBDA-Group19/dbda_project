# %%
import pandas as pd

# %%
df= pd.read_csv("0c55be4384.csv")

# %%
df
# Out:
#           Time      AccV     AccML     AccAP  StartHesitation  Turn  Walking
# 0            0 -1.017303  0.105948 -0.067194                0     0        0  \
# 1            1 -1.019972  0.105369 -0.068920                0     0        0
# 2            2 -1.017942  0.103586 -0.069410                0     0        0
# 3            3 -1.017090  0.102103 -0.070308                0     0        0
# 4            4 -1.017065  0.104719 -0.070091                0     0        0
# ...        ...       ...       ...       ...              ...   ...      ...
# 122501  122501 -0.989730  0.041016 -0.104258                0     0        0
# 122502  122502 -0.989259  0.041015 -0.114746                0     0        0
# 122503  122503 -0.994135  0.038830 -0.114019                0     0        0
# 122504  122504 -0.994873  0.034182 -0.098410                0     0        0
# 122505  122505 -0.994873  0.034884 -0.081396                0     0        0
#
#         Valid   Task
# 0       False  False
# ...

# %%
df.isnull().sum()
# Out:
# Time               0
# AccV               0
# AccML              0
# AccAP              0
# StartHesitation    0
# Turn               0
# Walking            0
# Valid              0
# Task               0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# Sample data
x_values = df.Time
y1_values = df.AccV
y2_values = df.AccML
y3_values = df.AccAP

# Plotting
plt.plot(x_values, y1_values, color='red', label='AccV')
plt.plot(x_values, y2_values, color='green', label='AccML')
plt.plot(x_values, y3_values, color='blue', label='AccAP')

# Adding labels and title
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Line Graph with Multiple Y-columns')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x_values = df.Time
# y1_values = df.AccV
# y2_values = df.AccML
y3_values = df.AccAP
walking = df.Walking
turn = df.Turn
startHestation = df.StartHesitation

# Create a figure and axis
fig, ax1 = plt.subplots()

# Plotting numeric values on the first y-axis
ax1.plot(x_values, y1_values, color='red', label='AccV')
# ax1.plot(x_values, y2_values, color='green', label='AccML')
# ax1.plot(x_values, y3_values, color='blue', label='AccAP')
ax1.set_xlabel('X values')
ax1.set_ylabel('Numeric Values', color='black')
ax1.tick_params(axis='y', labelcolor='black')

# Create a second y-axis for action stages
ax2 = ax1.twinx()
ax2.plot(x_values, walking, color='orange', linestyle='--', label='Walking')
ax2.plot(x_values, turn, color='purple', linestyle='--', label='Turn')
ax2.plot(x_values, startHestation, color='pink', linestyle='--', label='StartHestation')
ax2.set_ylabel('Action Stages', color='black')
ax2.tick_params(axis='y', labelcolor='black')

# Adding title and legends
plt.title('Combined Line Graph with Numeric Values and Action Stages')
lines = ax1.get_lines() + ax2.get_lines()
labels = [line.get_label() for line in lines]
plt.legend(lines, labels, loc='upper left')

# Display the plot
plt.show()
